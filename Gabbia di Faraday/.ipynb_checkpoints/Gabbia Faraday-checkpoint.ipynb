# %%
import pandas as pd
import numpy as np
import requests
from io import BytesIO
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit


url =  "https://unipa-my.sharepoint.com/:x:/g/personal/mattia_tarantino02_you_unipa_it/IQA-0r1AndU1T43HxvIdgSngAVKON4a9IE2ZQVRP0imPRo4?download=1"
def Leggi_File_excel(url, sheet_name = 0):

    response = requests.get(url)
    response.raise_for_status()

    excel_file = BytesIO(response.content)
    df = pd.read_excel(excel_file, sheet_name = sheet_name)
    return df

def Linear_Fit(m, q, x):

    return m*x + q

def Voltage_Fit( Area, Voltage, x, epsilon_0 = 8.9e-12):

    return epsilon_0 * Area *Voltage/x
   

df = Leggi_File_excel(url,0)

#print(df)

Col_1 = "d (cm)"

Col_2 = "V"

d = df[Col_1].to_numpy()
V = df[Col_2].to_numpy()

d_0 = d[~np.isnan(d)]
d_0/=100
V_0 = V[~np.isnan(V)]

epsilon_0 = 8.9e-12
#Unità di misura in metri
"""Il Raggio Del condensatore"""
R_cond = 8.9e-2
Err_d = 5e-4
Errore_Raggio_Cond = 0.1e-3
Err_V = 0.25


"""Raggio Sfera"""
R_sph = 6.0e-2
Err_sph = 5e-4

Circonferenza = 2*R_sph*np.pi

print(Circonferenza)

Area_Condensatore = (R_cond**2)*np.pi
Errore_Area_Condensatore = 2* R_cond * Errore_Raggio_Cond * np.pi
Capacita_Eletrometro = 27e-12

Distanza_Teorica = epsilon_0 * Area/Capacita_Eletrometro
""" Il ± si fa con 241"""
print(Distanza_Teorica)
print(f"Area Condensatore: {Area_Condensatore} ± {Errore_Area_Condensatore}")
# Out:
# 0.37699111843077515
# 0.008202686782994602
# Area Condensatore: 0.024884555409084748 ± 5.592034923389832e-05

# %% [markdown]
# # Grafici

# %%
fig , ax = plt.subplots(figsize = (6,5))

ax.errorbar(d_0,V_0, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3)
ax.set_xlabel("Distanza in metri")
ax.set_ylabel("Volt")
ax.grid(True)
ax.set_title("Grafico V in funzione di d")
ax.axvline(x = Distanza_Teorica, color = "red", linestyle = "--")

# %%
df = Leggi_File_excel(url, 1)

d = df[Col_1].to_numpy()
V = df[Col_2].to_numpy()

d_1 = d[~np.isnan(d)]
d_1/=100
V_1 = V[~np.isnan(V)]

# %%
fig , ax = plt.subplots(figsize = (6,5))

ax.errorbar(d_1,V_1, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3)
ax.set_xlabel("Distanza in metri")
ax.set_ylabel("Volt")
ax.grid(True)
ax.set_title("Grafico V in funzione di d")
ax.axvline(x = Distanza_Teorica, color = "red", linestyle = "--")

# %%
df = Leggi_File_excel(url, 2)

d = df[Col_1].to_numpy()
V = df[Col_2].to_numpy()

d_2 = d[~np.isnan(d)]
d_2/=100
V_2 = V[~np.isnan(V)]

# %%
fig , ax = plt.subplots(figsize = (6,5))

ax.errorbar(d_2,V_2, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3)
ax.set_xlabel("Distanza in metri")
ax.set_ylabel("Volt")
ax.grid(True)
ax.set_title("Grafico V in funzione di d")
ax.axvline(x = Distanza_Teorica, color = "red", linestyle = "--")

# %% [markdown]
# # Tutti i set

# %%
fig , ax = plt.subplots(figsize = (6,5))

ax.errorbar(d_0,V_0, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3,label = "Primo set")
ax.errorbar(d_1,V_1, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3, label = "Secodo set", alpha = 0.6)
ax.errorbar(d_2,V_2, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3, label = "Terzo set")
ax.set_xlabel("Distanza in metri")
ax.set_ylabel("Volt")
#ax.grid(True)
ax.legend()
ax.set_title("Grafico V in funzione di d")
ax.axvline(x = Distanza_Teorica, color = "red", linestyle = "--")

fig.savefig("Grafico-del-16-03-2026", dpi = 300, bbox_inches = "tight")

# %% [markdown]
# # Ponendo Il Voltaggio a 1000 V

# %%
df = Leggi_File_excel(url, 3)

d = df[Col_1].to_numpy()
V = df[Col_2].to_numpy()

d_3 = d[~np.isnan(d)]
d_3/=100
V_3 = V[~np.isnan(V)]



fig , ax = plt.subplots(figsize = (6,5))

ax.errorbar(d_3,V_3, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3,label = "Quarto set")
ax.set_xlabel("Distanza in metri")
ax.set_ylabel("Volt")
ax.legend()
ax.set_title("Grafico V in funzione di d")
ax.axvline(x = Distanza_Teorica, color = "red", linestyle = "--")

# %%
df = Leggi_File_excel(url, 4)

d = df[Col_1].to_numpy()
V = df[Col_2].to_numpy()

d_4 = d[~np.isnan(d)]
d_4/=100
V_4 = V[~np.isnan(V)]



fig , ax = plt.subplots(figsize = (6,5))

ax.errorbar(d_4,V_4, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3,label = "Quarto set")
ax.set_xlabel("Distanza in metri")
ax.set_ylabel("Volt")
ax.legend()
ax.set_title("Grafico V in funzione di d")
ax.axvline(x = Distanza_Teorica, color = "red", linestyle = "--")

# %%
df = Leggi_File_excel(url, 5)

d = df[Col_1].to_numpy()
V = df[Col_2].to_numpy()

d_5 = d[~np.isnan(d)]
d_5/=100
V_5 = V[~np.isnan(V)]



fig , ax = plt.subplots(figsize = (6,5))

ax.errorbar(d_5,V_5, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3,label = "Quarto set")
ax.set_xlabel("Distanza in metri")
ax.set_ylabel("Volt")
ax.legend()
ax.set_title("Grafico V in funzione di d")
ax.axvline(x = Distanza_Teorica, color = "red", linestyle = "--")

# %% [markdown]
# # Tutti i set a 1000 V

# %%
fig , ax = plt.subplots(figsize = (6,5))

ax.errorbar(d_3,V_3, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3,label = "Primo set")
ax.errorbar(d_4,V_4, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3, label = "Secodo set")
ax.errorbar(d_5,V_5, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3, label = "Terzo set")
ax.set_xlabel("Distanza in metri")
ax.set_ylabel("Volt")
#ax.grid(True)
ax.legend()
ax.set_title("Grafico V in funzione di d")
ax.axvline(x = Distanza_Teorica, color = "red", linestyle = "--")

# %%
fig , ax = plt.subplots(figsize = (6,5))


ax.errorbar(d_0,V_0, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3,label = "Primo set del 13-03-2026")
ax.errorbar(d_1,V_1, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3, label = "Secondo set 13-03-2026")
ax.errorbar(d_2,V_2, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3, label = "Terzo set 13-03-2026")
ax.errorbar(d_3,V_3, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3,label = "Primo set 19-03-2026")
ax.errorbar(d_4,V_4, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3, label = "Secondo set 19-03-2026")
ax.errorbar(d_5,V_5, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3, label = "Terzo set 19-03-2026")
ax.set_xlabel("Distanza in metri")
ax.set_ylabel("Volt")
#ax.grid(True)
ax.legend()
ax.set_title("Grafico V in funzione di d")

fig.savefig("Grafici-complessivi", dpi = 300, bbox_inches = "tight")

# %% [markdown]
# # Analisi Dei Dati

# %%
# Unità di misura: V, m e C
V0 = 3000

C_sph = 4 * np.pi *epsilon_0 * R_sph**2

Err_C_sph = 4* np.pi * epsilon_0 * R_sph

Q_sph = C_sph * V0

Q_cond_t = Q_sph *(R_cond/(2*R_sph))**2

# Per la stima della carica che si trova sul condensatore considero i tratti in cui il condesatore restituisce un potenziale costante

V_0_const = V_0[5:]
V_1_const = V_1[15:]
V_2_const = V_2[5:]

print(V_0_const)

V_0_mean = np.mean(V_0_const)
V_1_mean = np.mean(V_1_const)
V_2_mean = np.mean(V_2_const)

std_V_0 = np.std(V_0_const)
Err_V_0 = std_V_0/np.sqrt(V_0_const.size)

std_V_1 = np.std(V_1_const)
Err_V_1 = std_V_1/np.sqrt(V_1_const.size)

std_V_2 = np.std(V_2_const)
Err_V_2 = std_V_2/np.sqrt(V_2_const.size)


print(f"V0 : {V_0_mean} +/- {Err_V_0}\nV1 : {V_1_mean} +/- {Err_V_1}\nV2 : {V_2_mean} +/- {Err_V_2}")

"""Per la stima della carica ora moltiplico la tensione media per la capacità del condensatore, ma ricordiamo che
in questo tratto la capacità del condensatore diventa trascurabile rispetto a quella interna dell'eletrometro, 
quindi la nostra stima si baserà sulla quantità
di carica che si trova sul condesatore dell'eletrometro"""

Q_cond_0 = V_0_mean * 27e-12
Err_Q_cond_0 = Err_V_0 * 2.7e-12


print(f"Q_0: {Q_cond_0} +/- {Err_Q_cond_0}\nQ_T: {Q_cond_t} +/- ")
# Out:
# [1.7 1.8 1.8 1.8 1.8 1.9 2.  1.9 2.1 2.1 2.  2.  2.4 2.2 2.1 2.1 2.1 2.1
#  2.1 2.1 2.1 2.1 2.1 2.1 2.1]
# V0 : 2.024 +/- 0.030609802351534387
# V1 : 2.586666666666667 +/- 0.03247791272256911
# V2 : 2.18 +/- 0.01788854381999831
# Q_0: 5.4648e-11 +/- 8.264646634914284e-14
# Q_T: 6.644176294225629e-10 +/-

# %% [markdown]
# # Set Con Voltaggio da 3000 V del 19-03-2026

# %%
del(d)

# %% [markdown]
# # Stima di Q a partire dal grafico del secondo punto

# %%
df = Leggi_File_excel(url, 6)

d = 5e-3

C_cond = epsilon_0 * Area
C_cond/=d

Col_1 = "V"
Col_2 = "n"

V = df[Col_1].to_numpy()
n = df[Col_2].to_numpy()

V_N_1 = V[~np.isnan(V)]
n_N_1 = n[~np.isnan(n)]


popt, pcov = curve_fit(Linear_Fit, V_N_1, n_N_1, p0 = [1, 0],sigma = Err_V, absolute_sigma = True)

print(popt)

q_1 , m_1 = popt

#Stimo l'errore di m prima di modificare quest'ultima

perr = np.sqrt(np.diag(pcov))

Err_m_1 = perr[0]


m_1 /= n.size
m_1 *=C_cond




Err_q = Err_m_1/n.size

print(m_1)
# Out:
# [0.05044794 0.11977037]
# 5.305169903539294e-13

# %%
df = Leggi_File_excel(url, 7)

d = 5e-3

C_cond = epsilon_0 * Area
C_cond/=d

Col_1 = "V"
Col_2 = "n"

V = df[Col_1].to_numpy()
n = df[Col_2].to_numpy()

V_N_2 = V[~np.isnan(V)]
n_N_2 = n[~np.isnan(n)]


popt, pcov = curve_fit(Linear_Fit, V_N_2, n_N_2, p0 = [1, 0],sigma = Err_V, absolute_sigma = True)

q_2 , m_2 = popt

print(popt)

print(f"Stampo m_2 prima di lavorarlo: {m_2}")

y_fit_2 = Linear_Fit(m_2,q_2,range(0,100))
#Stimo l'errore di m prima di modificare quest'ultima

perr = np.sqrt(np.diag(pcov))



Err_m_2 = perr[0]


m_2 /= n.size
m_2*=C_cond




Err_q = Err_m_2/n.size



print(m_2)
# Out:
# [-0.50982893  0.11995667]
# Stampo m_2 prima di lavorarlo: 0.11995666532701951
# 5.313421547334269e-13

# %%
df = Leggi_File_excel(url, 8)

d = 5e-3

C_cond = epsilon_0 * Area
C_cond/=d

Col_1 = "V"
Col_2 = "n"

V = df[Col_1].to_numpy()
n = df[Col_2].to_numpy()

V_N_3 = V[~np.isnan(V)]
n_N_3 = n[~np.isnan(n)]


popt, pcov = curve_fit(Linear_Fit, V_N_3, n_N_3, p0 = [1, 0],sigma = Err_V, absolute_sigma = True)

q_3 , m_3 = popt

print(popt)
#Stimo l'errore di m prima di modificare quest'ultima

perr = np.sqrt(np.diag(pcov))

Err_m_3 = perr[0]


m_3 /= n.size
m_3 *=C_cond




Err_q = Err_m_3/n.size

print(m_3)
# Out:
# [-0.35579611  0.1157272 ]
# 5.126079273162198e-13

# %%
fig , ax = plt.subplots(figsize = (6,5))


ax.errorbar(n_N_1,V_N_1, yerr = Err_V, fmt = ".", capsize = 3,label = "Primo Campionamento", alpha = 0.6)
ax.errorbar(n_N_2,V_N_2, yerr = Err_V, fmt = ".", capsize = 3, label = "Secodo Campionamento")
#ax.plot(range(0,100),y_fit_2, label = "Fit del secondo Campionamento")
ax.errorbar(n_N_3,V_N_3, yerr = Err_V, fmt = ".", capsize = 3, label = "Terzo Campionamento")

ax.set_xlabel("Trasferimenti di Carica")
ax.set_ylabel("Volt")
#ax.grid(True)
ax.legend()
ax.set_title("Grafico V in funzione del Numero di Trasferimenti")
# Out:
# Text(0.5, 1.0, 'Grafico V in funzione del Numero di Trasferimenti')

# %% [markdown]
# # Condensatore fisso a 3000 V  al variare di d

# %%
df = Leggi_File_excel(url, 10)


Col_1 = "d(cm)2"

Col_2 = "V2"

d = df[Col_1].to_numpy()
V = df[Col_2].to_numpy()

d_6 = d[~np.isnan(d)]
d_6/=100
V_6 = V[~np.isnan(V)]



"""Raggi in mm e altezze in cm"""

R_int_f = 9.85/2
R_ext_f = 14.34/2
h_int_f = 15.2
h_ext_f = 19

"""Converto tutto in metri"""

h_ext_f *= 1e-2
h_int_f *= 1e-2

R_int_f *= 1e-2
R_ext_f *= 1e-2



"""Errori Delle Misure Sopra Citate"""
"""Gli errori delle h sono le stesse
Idem per gli errori dei raggi"""
Err_h = 5e-4
Err_r_f = 5e-5

"""Area è la variabile che contiene l'area del condensatore"""

Q_cond_T_6 = epsilon_0 * Area * V0

Q_cond_T_6 /= d_6

"""Q_cond è un vettore che presenta Q al variare di d"""


C_f = 2*np.pi*h_int_f*epsilon_0
C_f/= np.log(R_ext_f/R_int_f)

V_6_mean = np.mean(V_6)

Q_f_s_6 = V_6*(C_f + 27e-12)


Q_f_s_6_mean = V_6_mean*(C_f + 27e-12)



print(C_f)
print(Q_f_s_6_mean)
# Out:
# 2.2631295203814312e-11
# 1.2159667324934506e-09

# %%
df = Leggi_File_excel(url, 11)


Col_1 = "d (cm)"

Col_2 = "V"

d = df[Col_1].to_numpy()
V = df[Col_2].to_numpy()

d_7 = d[~np.isnan(d)]
d_7/=100
V_7 = V[~np.isnan(V)]


Q_cond_T_7 = epsilon_0 * Area * V0

Q_cond_T_7 /= d_7

V_7_mean = np.mean(V_7)

Q_f_s_7 = V_7*(C_f + 27e-12)


Q_f_s_7_mean = V_7_mean*(C_f + 27e-12)


print(C_f)
print(Q_f_s_7_mean)
# Out:
# 2.2631295203814312e-11
# 1.0867542225662788e-09

# %%
df = Leggi_File_excel(url, 12)


Col_1 = "d (cm)"

Col_2 = "V"

d = df[Col_1].to_numpy()
V = df[Col_2].to_numpy()

d_8 = d[~np.isnan(d)]
d_8/=100
V_8 = V[~np.isnan(V)]


Q_cond_T_8 = epsilon_0 * Area * V0

Q_cond_T_8 /= d_8


V_8_mean = np.mean(V_8)

Q_f_s_8 = V_8*(C_f + 27e-12)


Q_f_s_8_mean = V_8_mean*(C_f + 27e-12)


print(C_f)
print(Q_f_s_8_mean)
# Out:
# 2.2631295203814312e-11
# 1.0610828629780991e-09

# %% [markdown]
# # Stima Del Q Teorico

# %%
Q_teorico =  Voltage_Fit(Area_Condensatore, V0, x = np.linspace(0.01, 0.1, 100))

# %%
fig , ax = plt.subplots(figsize = (6,5))


ax.errorbar(d_6,V_6, yerr = Err_V, fmt = ".", capsize = 3,label = "Primo Campionamento", alpha = 0.6)
ax.errorbar(d_7,V_7, yerr = Err_V, fmt = ".", capsize = 3, label = "Secodo Campionamento")
#ax.plot(range(0,100),y_fit_2, label = "Fit del secondo Campionamento")
ax.errorbar(d_8,V_8, yerr = Err_V, fmt = ".", capsize = 3, label = "Terzo Campionamento", color = "black", label = "Carica Teorica")
ax.plot(x = np.linspace(0.01, 0.1, 100), Q_teorico, linestyle = "--")
ax.set_xlabel("Distanza (m)")
ax.set_ylabel("Volt")
#ax.grid(True)
ax.legend()
ax.set_title("Grafico V in funzione della distanza")
# Out:
#   Cell In[45], line 8
#     ax.plot(x = np.linspace(0.01, 0.1, 100), Q_teorico, linestyle = "--")
#                                                                         ^
# SyntaxError: positional argument follows keyword argument

# %%
fig , ax = plt.subplots(figsize = (6,5))


ax.errorbar(d_6,Q_cond_T_6, yerr = 0, fmt = ".", capsize = 3,label = "Primo Campionamento", alpha = 0.6)
ax.errorbar(d_7,Q_cond_T_7, yerr = 0, fmt = ".", capsize = 3, label = "Secodo Campionamento")
#ax.plot(range(0,100),y_fit_2, label = "Fit del secondo Campionamento")
ax.errorbar(d_8,Q_cond_T_8, yerr = 0, fmt = ".", capsize = 3, label = "Terzo Campionamento")

ax.set_xlabel("Distanza(m)")
ax.set_ylabel("Q(C)")
#ax.grid(True)
ax.legend()
ax.set_title("Carica del condensatore al variare della Distanza(Teoricamente)")
# Out:
# Text(0.5, 1.0, 'Carica del condensatore al variare della Distanza(Teoricamente)')

# %%
fig , ax = plt.subplots(figsize = (6,5))


ax.errorbar(d_6,Q_f_s_6, yerr = 0, fmt = ".", capsize = 3,label = "Primo Campionamento", alpha = 0.6)
ax.errorbar(d_7,Q_f_s_7, yerr = 0, fmt = ".", capsize = 3, label = "Secodo Campionamento")
#ax.plot(range(0,100),y_fit_2, label = "Fit del secondo Campionamento")
ax.errorbar(d_8,Q_f_s_8, yerr = 0, fmt = ".", capsize = 3, label = "Terzo Campionamento")

ax.set_xlabel("Distanza(m)")
ax.set_ylabel("Q(C)")
#ax.grid(True)
ax.legend()
ax.set_title("Carica del condensatore al variare della Distanza(Sperimentalmente)")
# Out:
# Text(0.5, 1.0, 'Carica del condensatore al variare della Distanza(Sperimentalmente)')

# %%
df = Leggi_File_excel(url, 13)

d = df[Col_1].to_numpy()
V = df[Col_2].to_numpy()

d_9 = d[~np.isnan(d)]
d_9/=100
V_9 = V[~np.isnan(V)]



fig , ax = plt.subplots(figsize = (6,5))

ax.errorbar(d_9,V_9, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3,label = "Set Senza Dielettrico")
ax.set_xlabel("Distanza in metri")
ax.set_ylabel("Volt")
ax.legend()
ax.set_title("Grafico V in funzione di d")
# Out:
# Text(0.5, 1.0, 'Grafico V in funzione di d')

# %%
df = Leggi_File_excel(url, 14)

d = df[Col_1].to_numpy()
V = df[Col_2].to_numpy()

d_10 = d[~np.isnan(d)]
d_10/=100
V_10 = V[~np.isnan(V)]



fig , ax = plt.subplots(figsize = (6,5))

ax.errorbar(d_10,V_10, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3,label = "Set Con il dielettrico")
ax.set_xlabel("Distanza in metri")
ax.set_ylabel("Volt")
ax.legend()
ax.set_title("Grafico V in funzione di d")
# Out:
# Text(0.5, 1.0, 'Grafico V in funzione di d')

# %%
fig , ax = plt.subplots(figsize = (6,5))

ax.errorbar(d_10,V_10, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3,label = "Set Con il dielettrico")
ax.errorbar(d_9,V_9, xerr = Err_d, yerr = Err_V, fmt = ".", capsize = 3,label = "Set senza il dielettrico")
ax.set_xlabel("Distanza in metri")
ax.set_ylabel("Volt")
ax.legend()
ax.set_title("Grafico V in funzione di d")
# Out:
# Text(0.5, 1.0, 'Grafico V in funzione di d')
