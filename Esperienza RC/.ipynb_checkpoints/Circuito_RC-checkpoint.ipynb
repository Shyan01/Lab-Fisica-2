# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.signal import find_peaks

# %%
def trova_massimi(time, voltage, prominence):
    # Trova i massimi locali con una soglia di prominenza per evitare falsi massimi
    peaks, _ = find_peaks(voltage, prominence=prominence)  # Soglia regolabile
    time_peaks = time[peaks]
    voltage_peaks = voltage[peaks]
    return time_peaks, voltage_peaks

def trova_minimi(time, voltage, prominence):
    # Trova i minimi locali con una soglia di prominenza per evitare falsi minimi
    troughs, _ = find_peaks(-voltage, prominence=prominence)  # Soglia regolabile
    time_troughs = time[troughs]
    voltage_troughs = voltage[troughs]
    return time_troughs, voltage_troughs

# %%
def Tau(x, A, Tau):

    return (A * (np.exp(-x/Tau)))

# %%
def Tau_with_c(x, A, tau, C):

    return (A * np.exp(-x/tau) + C)

# %%
file_name = "Dente%2%R573.xlsx"
df = pd.read_excel(file_name)
#print(df)
Col_1 = "Time"
Col_2 = "Vc"
Col_3 = "Vg"
t = df[Col_1].to_numpy()
Vc = df[Col_2].to_numpy()
Vg = df[Col_3].to_numpy()

# %%
C = 2.2e-3
R = 573
tau_i = C*R 

Maxs, _ = find_peaks(Vc, prominence= 1)
Mins, _ = find_peaks(-Vc, prominence= 1)
dt_1 = t[Mins[i]:Maxs[k]:1]
dvc_1 = Vc[Mins[i]:Maxs[k]:1]
Error_Vg = 0.001

delta = dt_1 - t[Mins[i]]

#print(dt_0)

i = 0
k = 0

#print(f"Massimi: {Maxs} \n\n Minimi: {Mins}")

popt, pcov = curve_fit(Tau, delta, dvc_1, p0 = [1, (1/tau_i)],sigma = Error_Vg, absolute_sigma = True)

A_fit, Tau_fit = popt
print(f"1 su Tau Reale: {Tau_fit}")
Tau_r = 1/Tau_fit
print(f"Tau Reale: {Tau_r}")

print(f"Erorri parametri A e Tau: {np.sqrt(np.diag(pcov))}")
delta_t = t[Maxs[k]] - t[Mins[i]]
print(f"Delta t :{delta_t}")
print(f"Il tau ideale: {tau_i}")
# Out:
# 1 su Tau Reale: 626953847.8180234
# Tau Reale: 1.5950137374230697e-09
# Erorri parametri A e Tau: [3.19408827e-05 8.30750128e+11]
# Delta t :16.785
# Il tau ideale: 1.2606000000000002

# %%
popt, pcov = curve_fit(Tau_with_c, delta, dvc_1, p0 = [1, (1/tau_i),-1],sigma = Error_Vg, absolute_sigma = True)

A_fit, Tau_fit, C_fit = popt

print(Tau_fit)
print(f"Erorri parametri A e Tau e C: {np.sqrt(np.diag(pcov))}")
# Out:
# 1.4815018447191626
# Erorri parametri A e Tau e C: [1.15797771e-04 1.48955776e-04 2.14120560e-05]

# %%
plt.figure(figsize = (10,8))

plt.subplot(2, 2, 1)
plt.plot(delta, dvc_1)

# %%
file_name = "Dente 1 R215.xlsx"

df = pd.read_excel(file_name)
#print(df)
Col_1 = "Tempi"
Col_2 = "Vc"
Col_3 = "Vg"
t_1 = df[Col_1].to_numpy()
Vc_1 = df[Col_2].to_numpy()
Vg_1 = df[Col_3].to_numpy()

# %%
C = 2.2e-3
R = 215
tau_i = C*R 

Maxs, _ = find_peaks(Vc_1, prominence = 1)
Mins, _ = find_peaks(-Vc_1, prominence = 1)

i = 44
k = 1

dt_2 = t_1[Mins[i]:Maxs[k]:1]
dvc_2 = Vc_1[Mins[i]:Maxs[k]:1]
Error_Vg = 0.001

#print(f"Stampo il dt_2: {delta_1}")

delta_1 = dt_2 - t_1[Mins[i]]

print(f"Massimi: {Maxs} \n\n Minimi: {Mins}")

#popt, pcov = curve_fit(Tau, delta_1, dvc_2, p0 = [2, 1/tau_i],sigma = Error_Vg, absolute_sigma = True)

#A_fit, Tau_fit= popt
#print(f"1 su Tau Reale: {Tau_fit}")
#Tau_r = 1/Tau_fit
print(f"\nTau Ideale: {tau_i}\n")
#print(f"Tau Reale: {Tau_r}")


#print(f"Erorri parametri A e Tau: {np.sqrt(np.diag(pcov))}")

delta_t = t_1[Maxs[k]] - t_1[Mins[i]]
print(f"Delta t :{delta_t}")
# Out:
# Massimi: [3827 7587]
#
#  Minimi: [ 5174  5248  5367  5370  5378  5579  5593  5597  5613  5638  5649  5664
#   5684  5753  5765  5799  5806  5813  5831  5839  5856  5888  5894  5902
#   5906  5918  5920  5937  5950  5952  5955  5960  5964  5972  5978  5999
#   6004  6006  6011  6013  6024  6027  6038  6050  6065  9908 10085 10131
#  10257 10263 10272 10289 10297 10308 10315 10318 10320 10327 10333 10335
#  10351 10353 10356 10363 10375 10384 10391 10401 10403 10422 10432]
# 1 su Tau Reale: 240526489.8179295
#
# Tau Ideale: 0.47300000000000003
#
# Tau Reale: 4.157546226018458e-09
# Erorri parametri A e Tau: [4.83667938e-05 4.21174950e+11]
# Delta t :7.610000000000003

# %%
popt, pcov = curve_fit(Tau_with_c, delta_1, dvc_2, p0 = [2, (1/tau_i),-1],sigma = Error_Vg, absolute_sigma = True)

A_fit, Tau_fit, C_fit = popt

print(Tau_fit)
print(f"Erorri parametri A e Tau e C: {np.sqrt(np.diag(pcov))}")
# Out:
# 0.576426608613107
# Erorri parametri A e Tau e C: [1.84666553e-04 7.36313737e-05 3.07020236e-05]

# %%
plt.figure(figsize = (10,8))

plt.subplot(2, 2, 1)
plt.plot(delta_1, dvc_2)

# %%
file_name = "Dente 3 R1397.xlsx"

df = pd.read_excel(file_name)
#print(df)
Col_1 = "Tempi"
Col_2 = "Vc"
Col_3 = "Vg"
t_2 = df[Col_1].to_numpy()
Vc_2 = df[Col_2].to_numpy()
Vg_2 = df[Col_3].to_numpy()

# %%
C = 2.2e-3
R = 1397
tau_i = C*R 

Maxs, _ = find_peaks(Vc_2, prominence = 0.01)
Mins, _ = find_peaks(-Vc_2, prominence = 0.01)

i = 0
k = 0

dt_3 = t_2[Mins[i]:Maxs[k]:1]
dvc_3 = Vc_2[Mins[i]:Maxs[k]:1]
Error_Vg = 0.001

delta_3 = dt_3 - t_2[Mins[i]]
#print(f"Massimi: {Maxs} \n\n Minimi: {Mins}")

#print(dvc_3)

popt, pcov = curve_fit(Tau, dt_3, dvc_3, p0 = [-1, 1],sigma = Error_Vg, absolute_sigma = True)

A_fit, Tau_fit = popt
print(f"1 su Tau Reale: {Tau_fit}")
Tau_r = 1/Tau_fit
print(f"\nTau Ideale: {tau_i}\n")
print(f"Tau Reale: {Tau_r}")


print(f"Erorri parametri A e Tau: {np.sqrt(np.diag(pcov))}")

delta_t = t_2[Maxs[k]] - t_2[Mins[i]]
print(f"Delta t :{delta_t}")
# Out:
# 1 su Tau Reale: 0.8458957971321438
#
# Tau Ideale: 3.0734000000000004
#
# Tau Reale: 1.1821787073423446
# Erorri parametri A e Tau: [5.36919155e+03 1.47045867e-04]
# Delta t :26.195

# %%
popt, pcov = curve_fit(Tau_with_c, delta_3, dvc_3, p0 = [1, (1/tau_i),-1],sigma = Error_Vg, absolute_sigma = True)

A_fit, Tau_fit, C_fit = popt

print(Tau_fit)
print(f"Erorri parametri A e Tau e C: {np.sqrt(np.diag(pcov))}")
# Out:
# 3.6425505843166426
# Erorri parametri A e Tau e C: [7.40009323e-05 2.39471790e-04 2.05824023e-05]
# C:\Users\Mattia\AppData\Local\Temp\ipykernel_24244\4206994038.py:3: RuntimeWarning: overflow encountered in exp
#   return (A * np.exp(-x/tau) + C)

# %%
plt.figure(figsize = (10,5))

plt.plot(dt_3,dvc_3 + 1)
plt.grid(True)
