# %%
import pandas as pd
import numpy as np
import requests
from io import BytesIO
import matplotlib.pyplot as plt
import random

# %%
def Errore_V(V):

    Err_V = (0.3/100) * V + 0.1
    return Err_V



def Leggi_File_excel(url, sheet_name = 0):

    response = requests.get(url)
    response.raise_for_status()

    excel_file = BytesIO(response.content)
    df = pd.read_excel(excel_file, sheet_name = sheet_name)
    return df

def rho_0(R, S, l):

    rho_0 =  R * (S/l)
    
    return rho_0
    
def Resistività(rho, delta_T, alpha):

    rho_0 = rho* (1 + alpha*delta_T)

    return rho_0

def Errore_R(R ,n = 1 , Str = 0.1):

    Err_R = (n/100) * R + Str

# %%
url = "https://unipa-my.sharepoint.com/:x:/g/personal/mattia_tarantino02_you_unipa_it/IQConB6ptybnSInToNNbGmPNAb7ULY-_ohF0_XHVQoU6qiI?download=1"
df = Leggi_File_excel(url, 0)
#print(df)

Col_1 = 'R'
Col_2 = 'V'
Col_3 = 'l'
Col_4 = 'S'
Col_5 = 'T'

R = df[Col_1].to_numpy()
R = R[~np.isnan(R)]

V = df[Col_2].to_numpy()
V = V[~np.isnan(V)]

l = df[Col_3].to_numpy()
l = l[~np.isnan(l)]

S = df[Col_4].to_numpy()
S = S[~np.isnan(S)]

T = df[Col_5].to_numpy()
T = T[~np.isnan(T)]
print(col)

T_0 = 25
delta_T = T - T_0
# Out:
#     R   V   l   S   T
# 0  13  23  21  17  15
# 1  12  14  53  12  14
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       2 df = Leggi_File_excel(url, 0)
#       3 print(df)
# ----> 5 Col_1
#       6 Col_2
#       8 print(col)
#
# NameError: name 'Col_1' is not defined
